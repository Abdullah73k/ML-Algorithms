# %%
# install github clone - allows for easy cloning of subdirectories
# !pip install github-clone
from pathlib import Path 

# clone datasets
if not Path('chapter_8_datasets').is_dir():
    # !ghclone https://github.com/neonwatty/machine-learning-refined-notes-assets/tree/main/notes/8_Linear_unsupervised_learning/chapter_8_datasets
else:
    print('chapter_8_datasets already cloned!')

# clone library subdirectory
if not Path('chapter_8_library').is_dir():
    # !ghclone https://github.com/neonwatty/machine-learning-refined-notes-assets/tree/main/notes/8_Linear_unsupervised_learning/chapter_8_library
else:
    print('chapter_8_library already cloned!')

# clone images
if not Path('chapter_8_images').is_dir():
    # !ghclone https://github.com/neonwatty/machine-learning-refined-notes-assets/tree/main/notes/8_Linear_unsupervised_learning/chapter_8_images
else:
    print('chapter_8_images already cloned!')

# clone videos
if not Path('chapter_8_videos').is_dir():
    # !ghclone https://github.com/neonwatty/machine-learning-refined-notes-assets/tree/main/notes/8_Linear_unsupervised_learning/chapter_8_videos
else:
    print('chapter_8_videos already cloned!')

## run universally whether in collab or local ##
# append path for local library, data, and image import
import sys
sys.path.append('./chapter_8_library') 
sys.path.append('./chapter_8_images') 
sys.path.append('./chapter_8_datasets') 

# import section helper
import section_8_3_helpers

# dataset paths
dataset_path_1 = 'chapter_8_datasets/2d_span_data.csv'
dataset_path_2 = 'chapter_8_datasets/3d_span_data.csv'

# image paths
image_path_1 = "chapter_8_images/pca_classic.png"
image_path_2 = "chapter_8_images/Fig_9_7.png"

# standard imports
import matplotlib.pyplot as plt
from IPython.display import Image
import autograd.numpy as np
from matplotlib import gridspec

# this is needed to compensate for matplotlib notebook's tendancy to blow up images when plotted inline
# %matplotlib inline
from matplotlib import rcParams
rcParams['figure.autolayout'] = True

# %load_ext autoreload
# %autoreload 2
# Out:
# Collecting github-clone
#   Downloading github_clone-1.2.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: requests>=2.20.0 in /Users/abdullah/Desktop/ML_Algorithms/.venv/lib/python3.8/site-packages (from github-clone) (2.32.4)
# Collecting docopt>=0.6.2 (from github-clone)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/abdullah/Desktop/ML_Algorithms/.venv/lib/python3.8/site-packages (from requests>=2.20.0->github-clone) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abdullah/Desktop/ML_Algorithms/.venv/lib/python3.8/site-packages (from requests>=2.20.0->github-clone) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/abdullah/Desktop/ML_Algorithms/.venv/lib/python3.8/site-packages (from requests>=2.20.0->github-clone) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abdullah/Desktop/ML_Algorithms/.venv/lib/python3.8/site-packages (from requests>=2.20.0->github-clone) (2026.2.25)
# Downloading github_clone-1.2.0-py3-none-any.whl (9.1 kB)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13703 sha256=e9ad9f414ce6c8569ee7177b9f7c4b041e24cc89c73332ae34779fbe65a7fa83
#   Stored in directory: /Users/abdullah/Library/Caches/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built docopt
# Installing collected packages: docopt, github-clone
# Successfully installed docopt-0.6.2 github-clone-1.2.0
# Cloning into 'chapter_8_datasets'...
# done.
# Cloning into 'chapter_8_library'...
# done.
# Cloning into 'chapter_8_images'...
# done.
# Cloning into 'chapter_8_videos'...
# done.

# %%
# here the weight matrix is loaded in a single list w = [C]
def least_squares(w):  
    # strip off C parameter
    C = w[0]
    
    # autoencoder constraint: encoder is C^T
    W = C.T 
    
    # compute the least squares cost
    cost = np.sum((np.dot(C, np.dot(W, X)) - X)**2)
    return cost/float(X.shape[1])

# %%
# load in dataset
X_original = np.loadtxt(dataset_path_2,delimiter=',')

# center data
X_means = np.mean(X_original,axis=1)[:,np.newaxis]
X = X_original - X_means

# run gradient descent to minimize the Least Squares cost for linear regression
g = least_squares; max_its = 100; alpha_choice = 10**(-3);

# set up initialization
scale = 0.1;
C = scale*np.random.randn(3,2)
w = [C] # Only initialize C

# run gradient descent
weight_history,cost_history = section_8_3_helpers.gradient_descent(g,alpha_choice,max_its,w)

# %%
# produce visuals
C = weight_history[-1][0]
view = [15,105]
section_8_3_helpers.project_data_from_3d_to_2d(X,C,view)
